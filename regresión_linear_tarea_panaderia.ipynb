# %% [markdown]
# <a href="https://colab.research.google.com/github/OscarGiordano/upsrj-aprendizaje-automatico/blob/develop/regresi%C3%B3n_linear_tarea_panaderia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TAREA
# 1. Genera un documento CSV que contenga 100 elementos con una variable dependiente y una variable independiente. La idea es que sea un caso de la vida real con un comportamiento linear como el ejemplo del precio de viviendas. Puedes usar IA para generar el archivo.
# 2. Genera un pipeline que haga lo siguiente:
# Escale los valores para evitar ruido en las unidades de los datos de nuestro CSV.
# Aplique un modelo de regresión lineal sobre los datos de nuestro CSV.
# 3. Grafica los valores de tus variables con matplotlib.pyplot
#
# El formato de entrega es un Jupyter Notebook en Colab respaldado en tu repositorio de upsrj-machine-learning con el nombre de LinearRegressionPractice.ipynb

# %%
# en este bloque se carga el archivo csv desde el disco local de nuestra computadora para empezar a trabajar
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-9d747943-f203-4882-bf05-b11f74d5480e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9d747943-f203-4882-bf05-b11f74d5480e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # **PLANTEAMIENTO DEL PROBLEMA**
# En una panadería se observa que entre más horas permanece abierto el local, mayores son las ventas del día.
#
# Variable independiente (X): Horas abiertas
#
# Variable dependiente (y): Ventas diarias (en pesos)

# %%
# aqui comenzamos importando nuestras librerias que vamos a utilizar para nuestro proyecto
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
np.random.seed(10)

horas_abierto = np.linspace(4, 14, 100)  # de 4 a 14 horas
ventas = 500 + 120 * horas_abierto + np.random.normal(0, 150, 100)

data = pd.DataFrame({
    "Horas_abierto": horas_abierto,
    "Ventas_pesos": ventas
})

data.to_csv("ventas_panaderia.csv", index=False)

data.head()
# Out:
#    Horas_abierto  Ventas_pesos
# 0        4.00000   1179.737976
# 1        4.10101   1099.413058
# 2        4.20202    772.432380
# 3        4.30303   1015.106059
# 4        4.40404   1121.685245

# %%
horas = [[10]]
pred = pipeline.predict(horas)

print(f"Ventas estimadas para 10 horas: ${pred[0]:.2f}")
# Out:
# Ventas estimadas para 10 horas: $1708.05
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
# aqui graficamos nuestra regresion linear
import matplotlib.pyplot as plt
y_pred = pipeline.predict(X)
plt.scatter(X, y, label="Datos reales")
plt.plot(X, y_pred, color="red", label="Regresión lineal")
plt.xlabel("Horas abierto")
plt.ylabel("Ventas (pesos)")
plt.title("Ventas diarias vs horas abierto (Panadería)")
plt.legend()
plt.grid(True)
plt.show()
